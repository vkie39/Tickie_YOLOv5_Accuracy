# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
print("현재 작업경로 : ",os.getcwd())
os.chdir('/content/drive/MyDrive')
# Out:
# 현재 작업경로 :  /content

# %%
print("현재 작업경로 : ",os.getcwd())
# Out:
# 현재 작업경로 :  /content/drive/My Drive/yolov5

# %%
# 처음에 한번만 실행 !
# !git clone https://github.com/ultralytics/yolov5  # YOLOv5 레퍼지토리 clone
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 16614, done.
# remote: Counting objects: 100% (92/92), done.
# remote: Compressing objects: 100% (65/65), done.
# remote: Total 16614 (delta 48), reused 56 (delta 27), pack-reused 16522
# Receiving objects: 100% (16614/16614), 15.09 MiB | 12.15 MiB/s, done.
# Resolving deltas: 100% (11407/11407), done.
# Updating files: 100% (148/148), done.

# %%
# %cd yolov5
# %pip install -qr requirements.txt
# %pip install -q roboflow
# Out:
# /content/drive/MyDrive/yolov5
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.3/207.3 kB 3.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 29.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 757.9/757.9 kB 26.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 5.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.3/21.3 MB 38.8 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# imageio 2.31.6 requires pillow<10.1.0,>=8.3.2, but you have pillow 10.3.0 which is incompatible.
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.9/74.9 kB 2.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.3/158.3 kB 8.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.7/178.7 kB 12.6 MB/s eta 0:00:00
# ...

# %%
import torch
import yaml
from IPython.display import Image, clear_output  # to display images

# %%
data_dir='/content/drive/MyDrive/dataset3/KickboardRider.v1i.yolov5pytorch'
data_yaml='/content/drive/MyDrive/dataset3/KickboardRider.v1i.yolov5pytorch/data.yaml'

# %%
# 데이터셋 yaml 파일 확인
with open(data_yaml) as f:
  film=yaml.load(f, Loader=yaml.FullLoader)
  display(film)
# Out:
# {'train': '../train/images',
#  'val': '../valid/images',
#  'test': '../test/images',
#  'nc': 1,
#  'names': ['kickboardP'],
#  'roboflow': {'workspace': 'project-fzasy',
#   'project': 'kickboardrider',
#   'version': 1,
#   'license': 'CC BY 4.0',
#   'url': 'https://universe.roboflow.com/project-fzasy/kickboardrider/dataset/1'}}

# %%
film['train']='/content/drive/MyDrive/dataset3/KickboardRider.v1i.yolov5pytorch/train/images'
film['val']='/content/drive/MyDrive/dataset3/KickboardRider.v1i.yolov5pytorch/test/images'

# %%
with open(data_yaml,'w') as f:
  yaml.dump(film,f)

print('변경된 yaml 파일 :')
with open(data_yaml) as f:
  film=yaml.load(f,Loader=yaml.FullLoader)
  display(film)
# Out:
# 변경된 yaml 파일 :
# {'names': ['kickboardP'],
#  'nc': 1,
#  'roboflow': {'license': 'CC BY 4.0',
#   'project': 'kickboardrider',
#   'url': 'https://universe.roboflow.com/project-fzasy/kickboardrider/dataset/1',
#   'version': 1,
#   'workspace': 'project-fzasy'},
#  'test': '../test/images',
#  'train': '/content/drive/MyDrive/dataset3/KickboardRider.v1i.yolov5pytorch/train/images',
#  'val': '/content/drive/MyDrive/dataset3/KickboardRider.v1i.yolov5pytorch/test/images'}

# %%
# !python train.py --img 416 --batch 16 --epochs 150 --weights yolov5s.pt --cache
# Out:
# 2024-05-21 15:28:16.511726: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-05-21 15:28:16.511806: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-05-21 15:28:16.514219: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# !python train.py --img 416 --batch 16 --epochs 80 --data /content/drive/MyDrive/dataset3/KickboardRider.v1i.yolov5pytorch/data.yaml --weights yolov5s.pt --cache
# Out:
# 2024-05-21 15:34:31.228151: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-05-21 15:34:31.228218: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-05-21 15:34:31.230380: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
#batch를 두배 늘려서 시행해봄
# !python train.py --img 416 --batch 32 --epochs 80 --data /content/drive/MyDrive/dataset3/KickboardRider.v1i.yolov5pytorch/data.yaml --weights yolov5s.pt --cache
# Out:
# 2024-05-21 18:19:36.714907: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-05-21 18:19:36.715000: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-05-21 18:19:36.717689: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
#이번엔 epochs를 늘려
# !python train.py --img 416 --batch 16 --epochs 150 --data /content/drive/MyDrive/dataset3/KickboardRider.v1i.yolov5pytorch/data.yaml --weights yolov5s.pt --cache
# Out:
# 2024-05-22 13:15:55.981346: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-05-22 13:15:55.981410: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-05-22 13:15:55.983165: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
#이번엔 둘 다 늘려보자
# !python train.py --img 416 --batch 32 --epochs 150 --data /content/drive/MyDrive/dataset3/KickboardRider.v1i.yolov5pytorch/data.yaml --weights yolov5s.pt --cache
# Out:
# 2024-05-22 17:53:20.553429: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-05-22 17:53:20.553601: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-05-22 17:53:20.689120: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
|"?|import tensor
# %load_ext tensorborsd
# %tensorboard --logdir runs
# Out:
#   File "<ipython-input-6-9af927e29401>", line 1
#     |"?|import tensor
#      ^
# SyntaxError: unterminated string literal (detected at line 1)

# %% [markdown]
# yolov5의 모델간의 성능을 비교해보고자 모두 동일한 명령어+cocodataset 으로 학습을 진행시킴

# %%
# !python train.py --img 416 --batch 16 --epochs 10 --weights yolov5n.pt --cache
# Out:
# 2024-05-26 15:48:18.078183: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-05-26 15:48:18.078329: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-05-26 15:48:18.237795: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# 학습에 약 2시간 30분 정도 소요됨
# !python train.py --img 416 --batch 16 --epochs 10 --weights yolov5m.pt --cache
# Out:
# 2024-05-26 15:59:21.527623: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-05-26 15:59:21.527683: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-05-26 15:59:21.529650: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
#시스템 RAM 한계를 넘어서 epochs 2 이상으로 못가는 경우가 생기는듯. 학습에 약 2시간 소요
# !python train.py --img 416 --batch 16 --epochs 10 --weights yolov5l.pt --cache
# Out:
# 2024-05-26 18:30:06.511322: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-05-26 18:30:06.511422: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-05-26 18:30:06.661350: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
#리소스 오버로 사용 불가능한듯

# !python train.py --img 416 --batch 16 --epochs 10 --weights yolov5x.pt --cache
# Out:
# 2024-05-26 20:31:04.399176: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-05-26 20:31:04.399264: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-05-26 20:31:04.537944: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...
